# %%
import pymysql
import mysql.connector 
import pandas as pd
import json
import streamlit as st

# %%
customers = pd.read_csv("bank transtract - Copy/customers.csv")
accounts = pd.read_csv("bank transtract - Copy/accounts.csv")
transactions = pd.read_csv("bank transtract - Copy/transactions.csv")
branches = pd.read_csv("bank transtract - Copy/branches.csv")
loans = pd.read_csv("bank transtract/loans.csv")
support_tickets = pd.read_csv("bank transtract - Copy/support_tickets.csv")
credit_cards = pd.read_json("bank transtract - Copy/credit_cards.json")

# %%
customers.head()
# Out:
#   customer_id              name gender  age            city account_type  \
# 0       C0001    Richard Wilson      M   65   Kimberlyburgh      Savings
# 1       C0002      Holly Parker      F   41      Port David      Current
# 2       C0003     Megan Alvarez      M   46  West Laurieton      Savings
# 3       C0004  Nicholas Stewart      F   39        Amyville      Current
# 4       C0005  Douglas Anderson      M   70   New Craigport      Current
#
#     join_date
# 0   8/27/2023
# 1   12/8/2023
# 2   5/25/2022
# 3  11/30/2020
# 4   1/29/2023

# %%
customers.isnull().sum()
# Out:
# customer_id     0
# name            0
# gender          0
# age             0
# city            0
# account_type    0
# join_date       0
# dtype: int64

# %%
conn= pymysql.connect(
    host="localhost",
    user="root",
    password="zeenathasma@733",
    database="banksight"
)
cursor=conn.cursor()

# %%
print(type(conn))
# Out:
# <class 'pymysql.connections.Connection'>

# %%
cursor.execute("CREATE DATABASE IF NOT EXISTS customer_data")
print("✅ Database created or already exists.")
# Out:
# ✅ Database created or already exists.

# %%
#CUSTOMERS
cursor.execute("""
CREATE TABLE IF NOT EXISTS customers (
    customer_id VARCHAR(10) PRIMARY KEY,
    name VARCHAR(50),
    gender CHAR(1),
    age INT,
    city VARCHAR(50),
    account_type VARCHAR(20),
    join_date DATE
)
               """)
 #ACCOUNTS_BALANCES
cursor.execute("""
CREATE TABLE IF NOT EXISTS account_balances (
  customer_id VARCHAR(50) PRIMARY KEY,
  account_balance DECIMAL(15,2),
  last_updated DATE,
  CONSTRAINT fk_acc_customer
    FOREIGN KEY (customer_id)
    REFERENCES customers(customer_id)
                 )
                 """)
#TRANSACTIONS
cursor.execute("""
               CREATE TABLE IF NOT EXISTS transactions (
  txn_id VARCHAR(50) PRIMARY KEY,
  customer_id VARCHAR(50),
  txn_type VARCHAR(50),
  amount DECIMAL(15,2),
  txn_time DATETIME,
  status VARCHAR(30),
  CONSTRAINT fk_txn_customer
    FOREIGN KEY (customer_id)
    REFERENCES customers(customer_id)
               )
               """)
#LOANS
cursor.execute("""
               CREATE TABLE IF NOT EXISTS loans (
  loan_id INT PRIMARY KEY,
  customer_id VARCHAR(50),
  account_id VARCHAR(50),
  branch VARCHAR(100),
  loan_type VARCHAR(50),
  loan_amount INT,
  interest_rate DECIMAL(5,2),
  loan_term_months INT,
  start_date DATE,
  end_date DATE,
  loan_status VARCHAR(30),
  CONSTRAINT fk_loan_customer
    FOREIGN KEY (customer_id)
    REFERENCES customers(customer_id))
               """)
#CREDIT_CARDS
cursor.execute("""
               CREATE TABLE IF NOT EXISTS credit_cards (
  card_id INT PRIMARY KEY,
  customer_id VARCHAR(50),
  account_id VARCHAR(50),
  branch VARCHAR(100),
  card_number VARCHAR(30),
  card_type VARCHAR(50),
  card_network VARCHAR(30),
  credit_limit INT,
  current_balance DECIMAL(15,2),
  issued_date DATE,
  expiry_date DATE,
  status VARCHAR(30),
  CONSTRAINT fk_card_customer
    FOREIGN KEY (customer_id)
    REFERENCES customers(customer_id))
               """)
#BRANCHES
cursor.execute("""
              CREATE TABLE IF NOT EXISTS branches (
  branch_id INT PRIMARY KEY,
  branch_name VARCHAR(150),
  city VARCHAR(100),
  manager_name VARCHAR(100),
  total_employees INT,
  branch_revenue DECIMAL(15,2),
  opening_date DATE,
  performance_rating INT)
              """)
#SUPPORT_TICKETS
cursor.execute("""CREATE TABLE IF NOT EXISTS support_tickets (
  ticket_id VARCHAR(50) PRIMARY KEY,
  customer_id VARCHAR(50),
  account_id VARCHAR(50),
  loan_id VARCHAR(50),
  branch_name VARCHAR(150),
  issue_category VARCHAR(100),
  description TEXT,
  date_opened DATE,
  date_closed DATE,
  priority VARCHAR(20),
  status VARCHAR(30),
  resolution_remarks TEXT,
  support_agent VARCHAR(100),
  channel VARCHAR(30),
  customer_rating INT,
  CONSTRAINT fk_ticket_customer
    FOREIGN KEY (customer_id)
    REFERENCES customers(customer_id)
)""")
# Out:
# 0

# %%
for _, row in customers.iterrows():
    cursor.execute
    ("""
        INSERT INTO customers ('customer_id', 'name, gender', 'age', 'city', 'account_type', 'join_date')
        VALUES ( %s , %s , %s , %s , %s , %s , %s )
    """, (row['customer_id'], row['name'], row['gender'], row['age'], row['city'], row['account_type'], row['join_date']))

conn.commit()

# %%
for _, row in accounts.iterrows():
    cursor.execute
    ("""
         INSERT INTO accounts ('customer_id','account_balance','last_updated')
     VALUES ( %s , %s , %s )
     """, (row['customer_id'], row['account_balance'], row['last_updated']))
     
    
conn.commit()

# %%
for _, row in transactions.iterrows():
    cursor.execute
    ("""
                   INSERT INTO transactions('txn_id','customer_id','txn_type','amount','txn_time','status')
      VALUES(%s , %s , %s , %s , %s , %s)
     """,(row['txn_id'],row['customer_id'],row['txn_id'],['amount'],row['txn_time'],row['status'])  
    )
    conn.commit()

# %%
for _, row in loans.iterrows():
    cursor.execute
    ("""
                   INSERT INTO loans ('Loan_ID','Customer_ID','Account_ID','Branch','Loan_Type','Loan_Amount','Interest_Rate','Loan_Term_Months','Start_Date', 'End_Date', 'Loan_Status')
     VALUES ( %s , %s , %s , %s , %s , %s , %s , %s , %s , %s , %s )
     """,(row ['Loan_ID'], row ['Customer_ID'], row ['Account_ID'], row ['Branch'], row ['Loan_Type'], row ['Loan_Amount'], row ['Interest_Rate'], row ['Loan_Term_Months'], row ['Start_Date'], row ['End_Date'], row ['Loan_Status']))
    
    conn.commit()

# %%
for _, row in branches.iterrows():
    cursor.execute
    ("""
     INSERT INTO branches ('Branch_ID','Branch_Name','City','Manager_Name','Total_Employees','Branch_Revenue','Opening_Date','Performance_Rating')
     VALUES ( %s , %s , %s , %s , %s ,%s , %s , %s )
     """, ( row['Branch_ID'], row['Branch_Name'], row['City'], row['Manager_Name'], row['Total_Employees'], row['Branch_Revenue'], row['Opening_Date'], row['Performance_Rating'])
     )
    conn.commit()

# %%
for _, row in support_tickets.iterrows():
    cursor.execute
    ("""
    INSERT INTO support_tickets ('Ticket_ID',	'Customer_ID',	'Account_ID',	'Loan_ID',	'Branch_Name',	'Issue_Category',	'Description',	'Date_Opened',	'Date_Closed',	'Priority',	'Status',	'Resolution_Remarks',	'Support_Agent',	'Channel',	'Customer_Rating')
    VALUES ( %s , %s , %s , %s , %s , %s , %s , %s , %s , %s , %s , %s , %s , %s ,%s)
    """, ( row['Ticket_ID'], row	['Customer_ID'],	row['Account_ID'],	row['Loan_ID'],	row['Branch_Name'],	['Issue_Category'],	row['Description'],	row['Date_Opened'],	row['Date_Closed'],	row['Priority'],	row['Status'],	row['Resolution_Remarks'],	row['Support_Agent'],   row	['Channel'], row['Customer_Rating'])
    )
    conn.commit()

# %%
for _, row in credit_cards.iterrows():
    cursor.execute
    ("""
          INSERT INTO credit_cards ('Card_ID' , 'Customer_ID' , 'Account_ID' , 'Branch' , 'Card_Number'  , 'Card_Type' , 'Card_Network' , 'Credit_Limit' , 'Current_Balance' , 'Issued_Date' , 'Expiry_Date' , 'Status')
     VALUES ( %s , %s , %s , %s , %s , %s , %s , %s , %s , %s , %s , %s)
     """, ( row['Card_ID'], row['Customer_ID'], row['Account_ID'], row['Branch'], row['Card_Number'], row['Card_Type'] , row['Card_Network'], row['Credit_Limit'], row['Current_Balance'], row['Issued_Date'], row['Expiry_Date'], row['Status'])
    )
    conn.commit()

# %%
from tabulate import tabulate

# %%
Query ="""
    SELECT customers.CITY,
COUNT(customers.customer_id)AS
TOTAL_CUSTOMERS,
AVG(account_balances.account_balance)AS
AVERAGE_BALANCES
FROM customers
LEFT JOIN account_balances
ON customers.customer_id=account_balances.customer_id
group by customers.city;"""
cursor.execute(Query)
result = cursor.fetchall()
headers = ["CITY","CUSTOMERS","AVERAGE ACCOUNT BALANCE"]
print("How Many Customers Exist Per City,And What is their Average Account Balance?")
print(tabulate(result,headers=headers))
# Out:
# How Many Customers Exist Per City,And What is their Average Account Balance?
# CITY                     CUSTOMERS    AVERAGE ACCOUNT BALANCE
# ---------------------  -----------  -------------------------
# Kimberlyburgh                    1                  293730
# Port David                       3                  209839
# West Laurieton                   1                  170156
# Amyville                         1                  311384
# New Craigport                    1                   60320.8
# North Cody                       1                   14846.8
# Kristaborough                    1                  291737
# Port Jenniferton                 1                    1669.73
# Port Nathan                      1                  118054
# Banksburgh                       1                   31868.5
# Kinghaven                        1                  498317
# Donnaton                         1                  180349
# West Williamview                 1                  279180
# Raymondtown                      1                  272658
# Terryside                        1                  373720
# Zacharyport                      1                  208294
# South Randyshire                 1                  345239
# Jaredland                        1                   24724.4
# Macdonaldborough                 1                  253086
# Randallshire                     1                  139707
# West Danielport                  1                   54943.9
# West Kathrynberg                 1                  322648
# Kristiville                      1                  352692
# North Michaelport                1                  327168
# Tinahaven                        1                  204252
# East Diana                       1                  315340
# Barbermouth                      1                   46322.2
# West Jessicamouth                1                  195269
# Robinsonchester                  1                  100024
# North Jeremy                     1                  350957
# South Maryshire                  1                  387714
# North Manuel                     1                   73729.6
# West Kennethburgh                1                  128139
# Leburgh                          1                  342018
# Berryberg                        1                  441089
# West David                       1                  170875
# Shermanborough                   1                  131626
# Virginiaburgh                    1                  267971
# Martinchester                    1                  390725
# Christopherstad                  1                  192213
# New Jennifer                     1                   55340.5
# Grantville                       1                  451228
# Dorisshire                       1                  403953
# Banksside                        1                  183201
# South Charles                    1                  414122
# Staceyburgh                      1                  132637
# Port Lindsey                     1                  450954
# Alanton                          1                  392509
# Herreraland                      1                  274628
# Hudsonfurt                       1                  354678
# Heatherland                      1                  420278
# Port Kimberly                    1                  303686
# East Nicholemouth                1                  392024
# Davisborough                     1                  331660
# Moyerburgh                       1                  192899
# Lake Antonioton                  1                  154228
# Darlenefurt                      1                  394979
# Lake Kathryn                     1                  436672
# West Joshua                      1                  155197
# Rowlandmouth                     1                  164035
# Lake Tanya                       1                  140728
# East Brianna                     1                  120794
# Hollyborough                     1                  131151
# Conniehaven                      1                  428047
# New Robertburgh                  1                  158826
# Stephanieville                   1                  182292
# Anneville                        1                  211699
# Thomasshire                      1                  221869
# New Crystalborough               1                  267754
# Andersonburgh                    1                  284739
# Grimesborough                    1                  459186
# East Deanstad                    1                  400752
# Taylormouth                      1                  236068
# Darrenmouth                      1                  432026
# Port Heather                     1                  442041
# Roberthaven                      1                  114070
# Walkerport                       1                  146992
# Port Joseph                      1                  150039
# Clarkchester                     1                  229510
# North Jennifer                   1                  260046
# Kennethview                      1                  230546
# New Stevefort                    1                  298158
# West Ronald                      1                  407686
# Lake Codyport                    1                   60361
# Nicholsonstad                    1                   71462.7
# Garyside                         1                  210818
# West Michelleville               1                   83536.5
# Orozcoshire                      1                  137153
# Mullenland                       1                  149136
# Shermanfurt                      1                  376153
# Nataliemouth                     1                  320254
# Millerstad                       1                  484758
# South Louismouth                 1                  454128

# %%
Query = """
    SELECT customers.account_type,
SUM(account_balances.account_balance)AS total_balance
FROM customers
JOIN account_balances
ON customers.customer_id=customers.customer_id
GROUP BY customers.account_type
ORDER by total_balance DESC
LIMIT 1;"""
cursor.execute(Query)
result = cursor.fetchall()
headers = ["ACCOUNT TYPE","HIGHEST TOTAL BALANCE"]
print("Which Account Type Holds the Highest Total Balance?",result)
print(tabulate(result,headers=headers))
# Out:
# Which Account Type Holds the Highest Total Balance?
# ACCOUNT TYPE      HIGHEST TOTAL BALANCE
# --------------  -----------------------
# Current                      3.0998e+10

# %%
Query = """

    select customers.customer_id,
customers.name,
SUM(account_balances.account_balance)
AS total_balance
FROM customers
JOIN account_balances
ON customers.customer_id=account_balances.customer_id
group by customers.customer_id,customers.name
ORDER BY total_balance DESC
LIMIT 10;"""
cursor.execute(Query)
result = cursor.fetchall()
headers = ["CUSTOMER ID","CUSTOMERS NAME","TOTAL ACCOUNT BALANCE"]
print("Who are the Top 10 Customers By Total Account Balance Across All Account Types?")
print(tabulate(result,headers=headers))
# Out:
# Who are the Top 10 Customers By Total Account Balance Across All Account Types?
# CUSTOMER ID    CUSTOMERS NAME        TOTAL ACCOUNT BALANCE
# -------------  ------------------  -----------------------
# C0314          Amy Nguyen                           498739
# C0011          Carolyn Higgins                      498317
# C0111          Lisa Russell                         497041
# C0392          Amber Williams                       494780
# C0077          Audrey Peck                          494700
# C0499          Alvin Compton                        484758
# C0338          Sharon Bennett DVM                   482746
# C0317          Denise Campbell                      481747
# C0220          Jeffrey Smith                        481568
# C0146          Ann Crosby                           479706

# %%
Query = """

    SELECT 
    customers.customer_id,
    customers.name,
    account_balances.account_balance,
    customers.join_date
FROM customers
JOIN account_balances
ON customers.customer_id = account_balances.customer_id
WHERE YEAR(customers.join_date) = 2023
  AND account_balances.account_balance > 100000;"""
cursor.execute(Query)
result = cursor.fetchall()
headers = ["CUSTOMER_ID","CUSTOMERS_NAME","ACCOUNT BALANCE","OPENED_DATE"]
print("Which Customers Opened Accounts in 2023 with a Balance Above ₹1,00,000?")
print(tabulate(result,headers = headers))
# Out:
# Which Customers Opened Accounts in 2023 with a Balance Above ₹1,00,000?
# CUSTOMER_ID    CUSTOMERS_NAME           ACCOUNT BALANCE  OPENED_DATE
# -------------  ---------------------  -----------------  -------------
# C0001          Richard Wilson                    293730  2023-08-27
# C0002          Holly Parker                      150735  2023-12-08
# C0007          Jasmine Morris                    291737  2023-10-09
# C0017          Jesus Davenport                   345239  2023-06-07
# C0021          William Jones                     185054  2023-04-01
# C0023          Jennifer Hodges                   447171  2023-02-11
# C0028          Adam Jones                        133670  2023-07-19
# C0032          John Novak                        155480  2023-10-29
# C0034          Vanessa Reese                     206242  2023-10-29
# C0046          Virginia Ayala                    294020  2023-05-15
# C0051          George Yates                      173261  2023-12-14
# C0052          Lori Bautista                     195239  2023-04-02
# C0053          Krystal Chaney                    402963  2023-06-15
# C0060          Nicole Logan                      192239  2023-03-05
# C0065          Michele Murphy                    346405  2023-05-18
# C0068          Lisa Gilbert                      460905  2023-05-04
# C0077          Audrey Peck                       494700  2023-03-21
# C0078          Jason Scott                       384430  2023-12-08
# C0079          Michael Ford                      297398  2023-12-25
# C0087          Pamela Harrison                   390869  2023-04-26
# C0100          Evan Duarte                       218111  2023-10-12
# C0102          Crystal Mckenzie                  446110  2023-06-29
# C0103          Stephanie Smith                   350927  2023-12-08
# C0105          Anna Davis                        270828  2023-09-16
# C0107          Julie Weeks                       134031  2023-11-24
# C0110          Mrs. Shelby Arroyo                390940  2023-11-08
# C0121          Tara Ellis                        228279  2023-05-24
# C0123          Paul Willis                       182899  2023-06-21
# C0125          Justin Rojas                      345673  2023-01-11
# C0128          Erica Brooks                      174479  2023-07-16
# C0133          Erica Morrison                    374537  2023-03-14
# C0411          Brendan Williams                  466808  2023-08-04
# C0416          Greg Gomez                        251101  2023-01-18
# C0418          Carol Bennett                     140163  2023-08-26
# C0432          Anthony Maldonado                 195269  2023-08-21
# C0433          Luke Bright                       100024  2023-03-07
# C0442          Melissa Prince                    267971  2023-10-06
# C0444          Caitlyn Sanchez                   192213  2023-10-09
# C0448          Randall Martin                    403953  2023-04-06
# C0449          Jasmine Cobb                      183201  2023-07-03
# C0450          Joseph Walton Jr.                 414122  2023-03-16
# C0451          Christopher Young                 132637  2023-03-14
# C0453          Kristen Henderson                 414405  2023-09-12
# C0468          Kari Jones                        120794  2023-03-30
# C0475          Laura Hicks                       267754  2023-12-14
# C0476          Daniel Butler PhD                 284739  2023-05-14
# C0478          Ryan Jackson                      400752  2023-04-18
# C0484          Rodney Cruz                       150039  2023-03-09
# C0489          Andrea Austin                     407686  2023-01-28
# C0499          Alvin Compton                     484758  2023-06-16
# C0500          Emily Brooks                      454128  2023-10-11

# %%
Query = """

 SELECT
    transactions.txn_type,
    SUM(amount) AS total_transaction_volume
FROM transactions
GROUP BY txn_type;"""
cursor.execute(Query)
result = cursor.fetchall()
headers = ["TRANSACTION TYPE","TOTAL TRANSACTION VOLUME"]
print("What is the Total Transaction Volume by Transaction Type?",result)
print(tabulate(result,headers = headers))
# Out:
# What is the Total Transaction Volume by Transaction Type? (('CREDIT', Decimal('300.00')), ('DEBIT', Decimal('300.00')), ('deposit', Decimal('197574827.47')), ('withdrawal', Decimal('151387322.23')), ('transfer', Decimal('50592799.65')), ('online fraud', Decimal('23829502.21')), ('purchase', Decimal('73834033.60')))
# TRANSACTION TYPE      TOTAL TRANSACTION VOLUME
# ------------------  --------------------------
# CREDIT                           300
# DEBIT                            300
# deposit                            1.97575e+08
# withdrawal                         1.51387e+08
# transfer                           5.05928e+07
# online fraud                       2.38295e+07
# purchase                           7.3834e+07

# %%
Query = """

  SELECT transactions.txn_type,
count(*) as FAILED_TRANSACTIONS
FROM transactions
WHERE status='failed'
group by txn_type;"""
cursor.execute(Query)
result = cursor.fetchall()
headers = ["TRANSACTION TYPE","FAILED TRANSACTION COUNTS"]
print("How Many Failed Transaction Occured For Each Transaction Type?",result)
print(tabulate(result,headers = headers))
# Out:
# How Many Failed Transaction Occured For Each Transaction Type? (('online fraud', 489), ('deposit', 433), ('withdrawal', 314), ('purchase', 167), ('transfer', 94))
# TRANSACTION TYPE      FAILED TRANSACTION COUNTS
# ------------------  ---------------------------
# online fraud                                489
# deposit                                     433
# withdrawal                                  314
# purchase                                    167
# transfer                                     94

# %%
Query = """

 SELECT transactions.txn_type,
count(amount)as TOTAL_NUMBER_OF_TRANSACTION
FROM transactions
group by txn_type;"""
cursor.execute(Query)
result = cursor.fetchall()
headers = ["TRANSACTION TYPE","NUMBER OF TRANSACTIONS"]
print("What is the Total Number of Transactions Per Transaction Type?",result)
print(tabulate(result,headers = headers))
# Out:
# What is the Total Number of Transactions Per Transaction Type? (('CREDIT', 1), ('DEBIT', 1), ('deposit', 3921), ('withdrawal', 3065), ('transfer', 1012), ('online fraud', 489), ('purchase', 1513))
# TRANSACTION TYPE      NUMBER OF TRANSACTIONS
# ------------------  ------------------------
# CREDIT                                     1
# DEBIT                                      1
# deposit                                 3921
# withdrawal                              3065
# transfer                                1012
# online fraud                             489
# purchase                                1513

# %%
Query = """

 SELECT 
    cc.account_id,
    COUNT(*) AS high_value_txn_count
FROM transactions t
JOIN credit_cards cc
    ON t.amount = cc.account_id
WHERE CAST(REPLACE(t.amount, ',', '') AS DECIMAL(10,2)) > 20000
GROUP BY cc.account_id
HAVING COUNT(*) >= 5;"""
cursor.execute(Query)
result = cursor.fetchall()
headers = ["ACCOUNT NAME","High_value_txn_count"]
print("Which Accounts Have 5 or More High-Value Transactions Above ₹20,000?",result)
print(tabulate(result,headers = headers))
# Out:
# Which Accounts Have 5 or More High-Value Transactions Above ₹20,000? ()
# ACCOUNT NAME    High_value_txn_count
# --------------  ----------------------

# %%
Query = """

 SELECT 
    loan_type,
    AVG(CAST(REPLACE(loan_amount, ',', '') AS DECIMAL(12,2))) AS avg_loan_amount,
    AVG(CAST(REPLACE(interest_rate, '%', '') AS DECIMAL(5,2))) AS avg_interest_rate
FROM loans
GROUP BY loan_type;"""
cursor.execute(Query)
headers = ["LOAN TYPE","AVERAGE AMOUNT" , "INTEREST RATE"]
result = cursor.fetchall()

print("What is the average loan amount and interest rate by loan type ?",result)
print(tabulate(result,headers = headers))
# Out:
# What is the average loan amount and interest rate by loan type ? (('Personal', Decimal('2461543.747826'), Decimal('10.463391')), ('Business', Decimal('2793968.873786'), Decimal('10.625437')), ('Auto', Decimal('2399260.981308'), Decimal('10.532523')), ('Home', Decimal('2344576.661157'), Decimal('10.872479')), ('Education', Decimal('2393947.700935'), Decimal('10.114393')), ('SAVINGS', Decimal('1000000.000000'), Decimal('1.490000')))
# LOAN TYPE      AVERAGE AMOUNT    INTEREST RATE
# -----------  ----------------  ---------------
# Personal          2.46154e+06          10.4634
# Business          2.79397e+06          10.6254
# Auto              2.39926e+06          10.5325
# Home              2.34458e+06          10.8725
# Education         2.39395e+06          10.1144
# SAVINGS           1e+06                 1.49

# %%
Query = """
 
          SELECT 
    loans.customer_id,
    customers.name,
    
    COUNT(*) AS active_approved_loan_count
FROM loans
join customers
on loans.customer_id=loans.customer_id
WHERE loan_status IN ('Active', 'Approved')
GROUP BY customer_id,name
HAVING COUNT(*) > 1;"""
cursor.execute(Query)
result_10 = cursor.fetchall()
headers = ["CUSTOMER ID","CUSTOMERS NAME" , "ACCOUNT HOLDING COUNT"]
print("Which customers currently hold more than one active or approved loan?",result)
print(tabulate(result,headers = headers))
# Out:
# Which customers currently hold more than one active or approved loan? (('Personal', Decimal('2461543.747826'), Decimal('10.463391')), ('Business', Decimal('2793968.873786'), Decimal('10.625437')), ('Auto', Decimal('2399260.981308'), Decimal('10.532523')), ('Home', Decimal('2344576.661157'), Decimal('10.872479')), ('Education', Decimal('2393947.700935'), Decimal('10.114393')), ('SAVINGS', Decimal('1000000.000000'), Decimal('1.490000')))
# CUSTOMER ID      CUSTOMERS NAME    ACCOUNT HOLDING COUNT
# -------------  ----------------  -----------------------
# Personal            2.46154e+06                  10.4634
# Business            2.79397e+06                  10.6254
# Auto                2.39926e+06                  10.5325
# Home                2.34458e+06                  10.8725
# Education           2.39395e+06                  10.1144
# SAVINGS             1e+06                         1.49

# %%
Query = """

 SELECT 
    c.customer_id,
    c.name,
    SUM(l.loan_amount) AS total_loan
FROM loans l
JOIN customers c
    ON l.customer_id = l.customer_id
WHERE l.loan_status != 'ACTIVE''APPROVED''DEFAULTED'
GROUP BY c.customer_id, c.name
ORDER BY total_loan DESC
LIMIT 5;"""
cursor.execute(Query)
result_11 = cursor.fetchall()
headers = ["CUSTOMER NAMES","HIGH LOAN AMOUNT"]
print("Who are the top 5 customers with the highest outstanding (non-closed) loan amount?",result)
print(tabulate(result, headers = headers))
# Out:
# Who are the top 5 customers with the highest outstanding (non-closed) loan amount? (('Personal', Decimal('2461543.747826'), Decimal('10.463391')), ('Business', Decimal('2793968.873786'), Decimal('10.625437')), ('Auto', Decimal('2399260.981308'), Decimal('10.532523')), ('Home', Decimal('2344576.661157'), Decimal('10.872479')), ('Education', Decimal('2393947.700935'), Decimal('10.114393')), ('SAVINGS', Decimal('1000000.000000'), Decimal('1.490000')))
#              CUSTOMER NAMES    HIGH LOAN AMOUNT
# ---------  ----------------  ------------------
# Personal        2.46154e+06             10.4634
# Business        2.79397e+06             10.6254
# Auto            2.39926e+06             10.5325
# Home            2.34458e+06             10.8725
# Education       2.39395e+06             10.1144
# SAVINGS         1e+06                    1.49

# %%
Query = """

 SELECT 
    b.branch_name,
    AVG(l.loan_amount) AS avg_loan_amount
FROM loans l
JOIN branches b
    ON l.branch = l.branch
GROUP BY b.branch_name;"""
cursor.execute(Query)
result_12 = cursor.fetchall()
headers = ["BRANCH","AVERAGE  LOAN AMOUNT"]
print("What is the average loan amount per branch?",result)
print(tabulate(result, headers = headers))
# Out:
# What is the average loan amount per branch? (('Personal', Decimal('2461543.747826'), Decimal('10.463391')), ('Business', Decimal('2793968.873786'), Decimal('10.625437')), ('Auto', Decimal('2399260.981308'), Decimal('10.532523')), ('Home', Decimal('2344576.661157'), Decimal('10.872479')), ('Education', Decimal('2393947.700935'), Decimal('10.114393')), ('SAVINGS', Decimal('1000000.000000'), Decimal('1.490000')))
#                 BRANCH    AVERAGE  LOAN AMOUNT
# ---------  -----------  ----------------------
# Personal   2.46154e+06                 10.4634
# Business   2.79397e+06                 10.6254
# Auto       2.39926e+06                 10.5325
# Home       2.34458e+06                 10.8725
# Education  2.39395e+06                 10.1144
# SAVINGS    1e+06                        1.49

# %%
Query = """

 SELECT 
    CASE
        WHEN age BETWEEN 18 AND 25 THEN '18–25'
        WHEN age BETWEEN 26 AND 35 THEN '26–35'
        WHEN age BETWEEN 36 AND 45 THEN '36–45'
        WHEN age BETWEEN 46 AND 60 THEN '46–60'
        ELSE '60+'
    END AS age_group,
    COUNT(*) AS customer_count
FROM customers
GROUP BY age_group
ORDER BY age_group;"""
cursor.execute(Query)
result = cursor.fetchall()
headers = ["AGE","CUSTOMERS COUNT"]
print("How many customers exist in each age group?",result)
print(tabulate(result, headers = headers))
# Out:
# How many customers exist in each age group? (('18–25', 79), ('26–35', 75), ('36–45', 101), ('46–60', 150), ('60+', 95))
# AGE      CUSTOMERS COUNT
# -----  -----------------
# 18–25                 79
# 26–35                 75
# 36–45                101
# 46–60                150
# 60+                   95

# %%
Query = """

SELECT
    issue_category,
    AVG(DATEDIFF(date_closed,date_opened)) AS avg_resolution_days
FROM
    support_tickets
WHERE
    date_closed IS NOT NULL
GROUP BY
    issue_category
ORDER BY
    avg_resolution_days DESC;"""
cursor.execute(Query)
result = cursor.fetchall()
headers = ["CATEGORIES","AVERAGE RESOLUTION TIME" ]
print("Which issue categories have the longest average resolution time?",result)
print(tabulate(result, headers = headers))
# Out:
# Which issue categories have the longest average resolution time? (('Card Not Working', Decimal('18.5000')), ('Mismatch in Account Statement', Decimal('17.9032')), ('Debit Card Delivery Delay', Decimal('17.8148')), ('UPI Payment Failed', Decimal('17.4583')), ('Account Closure Request', Decimal('17.3226')), ('Account Frozen', Decimal('17.1154')), ('Loan Foreclosure', Decimal('16.5833')), ('Cheque Bounce', Decimal('16.0000')), ('EMI Auto-debit Failed', Decimal('15.9762')), ('Online Transfer Failed', Decimal('15.4762')), ('KYC Update Required', Decimal('15.4074')), ('Interest Rate Dispute', Decimal('15.3103')), ('Account Access Issue', Decimal('14.8846')), ('Loan Payment Delay', Decimal('14.7115')), ('Unauthorized Transaction', Decimal('13.1071')))
# CATEGORIES                       AVERAGE RESOLUTION TIME
# -----------------------------  -------------------------
# Card Not Working                                 18.5
# Mismatch in Account Statement                    17.9032
# Debit Card Delivery Delay                        17.8148
# UPI Payment Failed                               17.4583
# Account Closure Request                          17.3226
# Account Frozen                                   17.1154
# Loan Foreclosure                                 16.5833
# Cheque Bounce                                    16
# EMI Auto-debit Failed                            15.9762
# Online Transfer Failed                           15.4762
# KYC Update Required                              15.4074
# Interest Rate Dispute                            15.3103
# Account Access Issue                             14.8846
# Loan Payment Delay                               14.7115
# Unauthorized Transaction                         13.1071

# %%
Query = """

SELECT
    support_agent,
    COUNT(*) AS critical_high_rated_tickets
FROM
    support_tickets
WHERE
    priority = 'Critical'
    AND customer_rating >= 4
    AND status = 'Resolved'
GROUP BY
    support_agent
ORDER BY
    critical_high_rated_tickets DESC
LIMIT 1;"""
cursor.execute(Query)
result = cursor.fetchall()
headers = ["SUPPORT AGENT","HIGH CUSTOMER RATING"]
print("Which support agents have resolved the most critical tickets with high customer ratings (≥4)?",result)
print(tabulate(result, headers = headers))
# Out:
# Which support agents have resolved the most critical tickets with high customer ratings (≥4)? (('Owen Mahajan', 4),)
# SUPPORT AGENT      HIGH CUSTOMER RATING
# ---------------  ----------------------
# Owen Mahajan                          4
